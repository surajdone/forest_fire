# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv("Algerian_forest_fires_dataset_UPDATE (3).csv",header=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.0+ KB

# %%
df.isnull().sum()
# Out:
# day            0
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# dtype: int64

# %%
df
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 241  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 242  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 243  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 244  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 245  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes
# 0    0.5   not fire
# 1    0.4   not fire
# ...

# %%
df.isnull().sum()
# Out:
# day            0
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  '],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 244 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    object
#  1   month        244 non-null    object
#  2   year         244 non-null    object
#  3   Temperature  244 non-null    object
#  4    RH          244 non-null    object
#  5    Ws          244 non-null    object
#  6   Rain         244 non-null    object
#  7   FFMC         244 non-null    object
#  8   DMC          244 non-null    object
#  9   DC           244 non-null    object
#  10  ISI          244 non-null    object
#  11  BUI          244 non-null    object
#  12  FWI          244 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 28.6+ KB

# %%
df.columns=df.columns.str.strip()

# %%
df[~df["day"].str.isnumeric()]
# Out:
#      day  month  year  Temperature   RH   Ws   Rain  FFMC  DMC  DC  ISI  BUI  \
# 123  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI
#
#      FWI    Classes
# 123  FWI  Classes

# %%
df.drop(123,inplace=True)

# %%
df[["day","month","year","Temperature","RH","Ws"]]=df[["day","month","year","Temperature","RH","Ws"]].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 243 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
# dtypes: int64(6), object(8)
# memory usage: 28.5+ KB

# %%
df[["Rain","FFMC","DMC","DC","ISI","BUI","FWI"]]=df[["Rain","FFMC","DMC","DC","ISI","BUI","FWI"]].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 243 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
# dtypes: float64(7), int64(6), object(1)
# memory usage: 28.5+ KB

# %%
df["Classes"].value_counts()
# Out:
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: Classes, dtype: int64

# %%
df["Classes"]=np.where(df["Classes"].str.contains("not fire"),0,1)

# %%
df
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 0      1      6  2012           29  57  18   0.0  65.7   3.4   7.6  1.3   3.4
# 1      2      6  2012           29  61  13   1.3  64.4   4.1   7.6  1.0   3.9
# 2      3      6  2012           26  82  22  13.1  47.1   2.5   7.1  0.3   2.7
# 3      4      6  2012           25  89  13   2.5  28.6   1.3   6.9  0.0   1.7
# 4      5      6  2012           27  77  16   0.0  64.8   3.0  14.2  1.2   3.9
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...   ...  ...   ...
# 241   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 242   27      9  2012           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2
# 243   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 244   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 245   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#      FWI  Classes
# ...

# %%
df.iloc[[123]]
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC   DC  ISI  BUI  \
# 125    2      6  2012           30  73  13   4.0  55.7  2.7  7.8  0.6  2.9
#
#      FWI  Classes
# 125  0.2        0

# %%
df.loc[:122,"region"]=0
df.loc[122:,"region"]=1

# %%
df
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 0      1      6  2012           29  57  18   0.0  65.7   3.4   7.6  1.3   3.4
# 1      2      6  2012           29  61  13   1.3  64.4   4.1   7.6  1.0   3.9
# 2      3      6  2012           26  82  22  13.1  47.1   2.5   7.1  0.3   2.7
# 3      4      6  2012           25  89  13   2.5  28.6   1.3   6.9  0.0   1.7
# 4      5      6  2012           27  77  16   0.0  64.8   3.0  14.2  1.2   3.9
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...   ...  ...   ...
# 241   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 242   27      9  2012           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2
# 243   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 244   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 245   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#      FWI  Classes  region
# ...

# %%
df["region"]=df["region"].astype(int)

# %%
df
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 0      1      6  2012           29  57  18   0.0  65.7   3.4   7.6  1.3   3.4
# 1      2      6  2012           29  61  13   1.3  64.4   4.1   7.6  1.0   3.9
# 2      3      6  2012           26  82  22  13.1  47.1   2.5   7.1  0.3   2.7
# 3      4      6  2012           25  89  13   2.5  28.6   1.3   6.9  0.0   1.7
# 4      5      6  2012           27  77  16   0.0  64.8   3.0  14.2  1.2   3.9
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...   ...  ...   ...
# 241   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 242   27      9  2012           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2
# 243   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 244   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 245   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#      FWI  Classes  region
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 243 entries, 0 to 245
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    int64
#  14  region       243 non-null    int64
# dtypes: float64(7), int64(8)
# memory usage: 38.5 KB

# %%
df.to_csv("all_clear_Data")

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('seaborn')
df.hist(bins=30,figsize=(25,30))
plt.show()
# Out:
# /tmp/ipykernel_217/3749510639.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
df.describe()
# Out:
#               day       month    year  Temperature          RH          Ws  \
# count  243.000000  243.000000   243.0   243.000000  243.000000  243.000000
# mean    15.761317    7.502058  2012.0    32.152263   62.041152   15.493827
# std      8.842552    1.114793     0.0     3.628039   14.828160    2.811385
# min      1.000000    6.000000  2012.0    22.000000   21.000000    6.000000
# 25%      8.000000    7.000000  2012.0    30.000000   52.500000   14.000000
# 50%     16.000000    8.000000  2012.0    32.000000   63.000000   15.000000
# 75%     23.000000    8.000000  2012.0    35.000000   73.500000   17.000000
# max     31.000000    9.000000  2012.0    42.000000   90.000000   29.000000
#
#              Rain        FFMC         DMC          DC         ISI         BUI  \
# count  243.000000  243.000000  243.000000  243.000000  243.000000  243.000000
# mean     0.762963   77.842387   14.680658   49.430864    4.742387   16.690535
# ...

# %%
df.corr()
# Out:
#                   day     month  year  Temperature        RH        Ws  \
# day          1.000000 -0.000369   NaN     0.097227 -0.076034  0.047812
# month       -0.000369  1.000000   NaN    -0.056781 -0.041252 -0.039880
# year              NaN       NaN   NaN          NaN       NaN       NaN
# Temperature  0.097227 -0.056781   NaN     1.000000 -0.651400 -0.284510
# RH          -0.076034 -0.041252   NaN    -0.651400  1.000000  0.244048
# Ws           0.047812 -0.039880   NaN    -0.284510  0.244048  1.000000
# Rain        -0.112523  0.034822   NaN    -0.326492  0.222356  0.171506
# FFMC         0.224956  0.017030   NaN     0.676568 -0.644873 -0.166548
# DMC          0.491514  0.067943   NaN     0.485687 -0.408519 -0.000721
# DC           0.527952  0.126511   NaN     0.376284 -0.226941  0.079135
# ISI          0.180543  0.065608   NaN     0.603871 -0.686667  0.008532
# BUI          0.517117  0.085073   NaN     0.459789 -0.353841  0.031438
# ...

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot: >

# %%
df1=pd.read_csv("all_clear_Data")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   243 non-null    int64
#  1   day          243 non-null    int64
#  2   month        243 non-null    int64
#  3   year         243 non-null    int64
#  4   Temperature  243 non-null    int64
#  5   RH           243 non-null    int64
#  6   Ws           243 non-null    int64
#  7   Rain         243 non-null    float64
#  8   FFMC         243 non-null    float64
#  9   DMC          243 non-null    float64
#  10  DC           243 non-null    float64
#  11  ISI          243 non-null    float64
#  12  BUI          243 non-null    float64
#  13  FWI          243 non-null    float64
#  14  Classes      243 non-null    int64
#  15  region       243 non-null    int64
# dtypes: float64(7), int64(9)
# memory usage: 30.5 KB

# %%
df.drop(["day","month","year"],axis=1,inplace=True)

# %%
df
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  Classes  \
# 0             29  57  18   0.0  65.7   3.4   7.6  1.3   3.4  0.5        0
# 1             29  61  13   1.3  64.4   4.1   7.6  1.0   3.9  0.4        0
# 2             26  82  22  13.1  47.1   2.5   7.1  0.3   2.7  0.1        0
# 3             25  89  13   2.5  28.6   1.3   6.9  0.0   1.7  0.0        0
# 4             27  77  16   0.0  64.8   3.0  14.2  1.2   3.9  0.5        0
# ..           ...  ..  ..   ...   ...   ...   ...  ...   ...  ...      ...
# 241           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5        1
# 242           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0        0
# 243           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2        0
# 244           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7        0
# 245           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5        0
#
#      region
# 0         0
# 1         0
# 2         0
# 3         0
# ...

# %%
x=df.drop("FWI",axis=1)
y=df["FWI"]

# %%
x
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  Classes  region
# 0             29  57  18   0.0  65.7   3.4   7.6  1.3   3.4        0       0
# 1             29  61  13   1.3  64.4   4.1   7.6  1.0   3.9        0       0
# 2             26  82  22  13.1  47.1   2.5   7.1  0.3   2.7        0       0
# 3             25  89  13   2.5  28.6   1.3   6.9  0.0   1.7        0       0
# 4             27  77  16   0.0  64.8   3.0  14.2  1.2   3.9        0       0
# ..           ...  ..  ..   ...   ...   ...   ...  ...   ...      ...     ...
# 241           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9        1       1
# 242           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2        0       1
# 243           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4        0       1
# 244           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1        0       1
# 245           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8        0       1
#
# [243 rows x 11 columns]

# %%
y
# Out:
# 0      0.5
# 1      0.4
# 2      0.1
# 3      0.0
# 4      0.5
#       ...
# 241    6.5
# 242    0.0
# 243    0.2
# 244    0.7
# 245    0.5
# Name: FWI, Length: 243, dtype: float64

# %%
df["Classes"].value_counts()
# Out:
# 1    137
# 0    106
# Name: Classes, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=30,random_state=42)

# %%
x_train.shape,y_train.shape
# Out:
# ((213, 11), (213,))

# %%
x_test.shape,y_test.shape
# Out:
# ((30, 11), (30,))

# %%
x_train.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.657738 -0.314863 -0.305580  0.678298  0.480547
# RH             -0.657738  1.000000  0.254075  0.221571 -0.650173 -0.401839
# Ws             -0.314863  0.254075  1.000000  0.203137 -0.202576 -0.002147
# Rain           -0.305580  0.221571  0.203137  1.000000 -0.525776 -0.285832
# FFMC            0.678298 -0.650173 -0.202576 -0.525776  1.000000  0.612785
# DMC             0.480547 -0.401839 -0.002147 -0.285832  0.612785  1.000000
# DC              0.384820 -0.229611  0.077214 -0.297993  0.522650  0.876318
# ISI             0.615559 -0.702556 -0.013500 -0.345483  0.747904  0.687475
# BUI             0.458084 -0.349064  0.027377 -0.296078  0.599432  0.983750
# Classes         0.533399 -0.435587 -0.075123 -0.376519  0.779273  0.612284
# region          0.250961 -0.382469 -0.159051 -0.041443  0.215949  0.181424
#
#                    DC       ISI       BUI   Classes    region
# ...

# %%
sns.heatmap(x_train.corr(),annot=True)
# Out:
# <AxesSubplot: >

# %%
x_train.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.657738 -0.314863 -0.305580  0.678298  0.480547
# RH             -0.657738  1.000000  0.254075  0.221571 -0.650173 -0.401839
# Ws             -0.314863  0.254075  1.000000  0.203137 -0.202576 -0.002147
# Rain           -0.305580  0.221571  0.203137  1.000000 -0.525776 -0.285832
# FFMC            0.678298 -0.650173 -0.202576 -0.525776  1.000000  0.612785
# DMC             0.480547 -0.401839 -0.002147 -0.285832  0.612785  1.000000
# DC              0.384820 -0.229611  0.077214 -0.297993  0.522650  0.876318
# ISI             0.615559 -0.702556 -0.013500 -0.345483  0.747904  0.687475
# BUI             0.458084 -0.349064  0.027377 -0.296078  0.599432  0.983750
# Classes         0.533399 -0.435587 -0.075123 -0.376519  0.779273  0.612284
# region          0.250961 -0.382469 -0.159051 -0.041443  0.215949  0.181424
#
#                    DC       ISI       BUI   Classes    region
# ...

# %%
def corelation(dataset,threshhold):
    col_corr=set()
    corr_matrix=dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j] > threshhold):
                colname=corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
corr_feature=corelation(x_train,0.85)

# %%
corr_feature
# Out:
# {'BUI', 'DC'}

# %%
x_train.drop(corr_feature,axis=1,inplace=True)

# %%
x_test.drop(corr_feature,axis=1,inplace=True)

# %%
x_train.shape,x_test.shape
# Out:
# ((213, 9), (30, 9))

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
x_train_scaled=scaler.fit_transform(x_train)

# %%
x_test_scaled=scaler.transform(x_test)

# %%
sns.boxplot(x_train)
# Out:
# <AxesSubplot: >

# %%
sns.boxplot(x_train_scaled)
# Out:
# <AxesSubplot: >

# %%
from sklearn.linear_model import LinearRegression

# %%
regresor=LinearRegression()

# %%
regresor
# Out:
# LinearRegression()

# %%
regresor.fit(x_train_scaled,y_train)
y_pread=regresor.predict(x_test_scaled)

# %%
y_pread
# Out:
# array([ 8.17520453,  7.72926621, -0.23857154,  4.37151338,  6.64470102,
#         1.42625932,  1.97762202,  7.79534141,  1.69544965,  3.31175183,
#         0.3671827 ,  9.7578371 ,  9.3246532 , 17.09129685, 18.53589842,
#         1.26180356,  1.86711637,  0.06456292,  7.14299582,  3.04381792,
#         1.43736313,  0.25337786,  6.53947675,  0.3450425 , 21.22536645,
#         5.13520372,  5.8686398 ,  9.7878986 , -0.02558222,  9.83486697])

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
mse=mean_squared_error(y_test,y_pread)
mae=mean_absolute_error(y_test,y_pread)
rmse=np.sqrt(mse)
print(mse)
print(mae)
print(rmse)
# Out:
# 0.7907260850039273
# 0.540120242181603
# 0.8892278026489766

# %%
from sklearn.metrics import r2_score

# %%
score=r2_score(y_test,y_pread)

# %%
score
# Out:
# 0.9754722012802185

# %% [markdown]
# # Ridge_Regression

# %%
from sklearn.linear_model import Ridge

# %%
ridge=Ridge()

# %%
ridge.fit(x_train_scaled,y_train)
y_pread=ridge.predict(x_test_scaled)

# %%
mse=mean_squared_error(y_test,y_pread)
mae=mean_absolute_error(y_test,y_pread)
rmse=np.sqrt(mse)
print(mse)
print(mae)
print(rmse)
# Out:
# 0.8025532287002458
# 0.5446947436019375
# 0.8958533522291725

# %%
score=r2_score(y_test,y_pread)

# %%
score
# Out:
# 0.9751053311269318

# %%
import pickle

# %%
pickle.dump(scaler,open("scaler.pkl","wb"))
pickle.dump(ridge,open("ridge.pkl","wb"))
